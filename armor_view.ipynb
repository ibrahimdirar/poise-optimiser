# %%
import pandas as pd

armor_types = ["head", "chest", "arms", "legs"]
armors = pd.concat( [pd.read_pickle(f"{armor_type}.pkl") for armor_type in armor_types], axis=0)
armors
# Out:
#                        Name   Phy VS Strike VS Slash VS Pierce  Mag  Fir  Lit  \
# 0    Alberich's Pointed Hat   1.8       1.4      1.8       1.8  4.6  4.2  4.4
# 1          All-Knowing Helm   4.6       4.2      4.8       4.2  4.4  3.4  3.6
# 2           Astrologer Hood   1.8       1.4      1.4       1.4  4.6  4.5  4.6
# 3               Bandit Mask   2.8       3.1      3.1       3.1  3.1  3.4  3.6
# 4      Banished Knight Helm   6.3       5.9      6.8       6.8  4.7  4.9  4.6
# ..                      ...   ...       ...      ...       ...  ...  ...  ...
# 52          Warrior Greaves   5.4       5.4      4.5       4.5  5.8  6.2  6.8
# 53  Vagabond Knight Greaves   7.4       5.8      6.8       6.5  5.0  5.8  4.5
# 54        Veteran's Greaves  10.8       9.8     10.8      10.1  7.7  8.1  7.3
# 55       White Reed Greaves   5.4       5.4      6.5       5.0  6.2  6.2  6.8
# 56           Zamor Legwraps   6.5       5.0      6.8       5.8  4.5  4.5  3.0
#
# ...
